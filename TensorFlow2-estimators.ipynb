# %% [markdown]
# # Using Estimators in TensorFlow 2.0
#
# `tf.estimator` is a high-level TensorFlow API. Estimators encapsulate the following actions:
# - training
# - evaluation
# - prediction
# - export for serving
#
# We may either use the pre-made Estimators provided or write our own custom [Estimators](https://www.tensorflow.org/guide/estimator).

# %%
# Import necessary modules
import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow import keras

# %%
# Read data
df = pd.read_csv('data/tf/house.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# I'll first define a list of feature columns, `feature_list`, and a data input function, `input_fn()`.

# %%
# Define feature columns for bedrooms and bathrooms
bedrooms = tf.feature_column.numeric_column("bedrooms")
bathrooms = tf.feature_column.numeric_column("bathrooms")

# Define the list of feature columns
feature_list = [bedrooms, bathrooms]

def input_fn():
    # Define the labels
    labels = np.array(df.price)
    # Define the features
    features = {'bedrooms':np.array(df['bedrooms']), 
                'bathrooms':np.array(df['bathrooms'])}
    return features, labels

# %% [markdown]
# I'll now use the feature columns and data input function to define and train an estimator.

# %%
# Define the model and set the number of steps
model = tf.estimator.DNNRegressor(feature_columns=feature_list, hidden_units=[2,2])
model.train(input_fn, steps=1)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/pb/d_xy0lzn7pl1jq62fsw6n9tm0000gp/T/tmpb5kinet1
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/pb/d_xy0lzn7pl1jq62fsw6n9tm0000gp/T/tmpb5kinet1', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# ...

# %%
# Define the model and set the number of steps
model = tf.estimator.LinearRegressor(feature_columns=feature_list)
model.train(input_fn, steps=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/pb/d_xy0lzn7pl1jq62fsw6n9tm0000gp/T/tmpsa16hw_d
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/pb/d_xy0lzn7pl1jq62fsw6n9tm0000gp/T/tmpsa16hw_d', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# ...
